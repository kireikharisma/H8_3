# %% [markdown]
# # PANDAS

# %% [markdown]
# ## Installing Pandas

# %% [markdown]
# Cara menginstall Pandas :
#
# - python -m pip install pandas
#
# atau
#
# - conda install pandas

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv ('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
len(df)
# Out:
# 126314

# %%
df.shape  #jumlah baris,kolom
# Out:
# (126314, 23)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
pd.set_option("display.max.columns", None)

# %%
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126309         100            1     CLE  Cavaliers   82  1723.4149  1704.3949
# 126310         102            1     GSW   Warriors  104  1809.9791  1813.6349
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# ...

# %%
df.tail(3)
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 126311         101            1     CLE  Cavaliers   91  1704.3949  1700.7391
# 126312         102            1     CLE  Cavaliers   97  1700.7391  1692.0859
# 126313         103            1     GSW   Warriors  105  1813.6349  1822.2881
#
#         win_equiv opp_id   opp_fran  opp_pts  opp_elo_i  opp_elo_n  \
# 126311  60.010067    GSW   Warriors      104  1809.9791  1813.6349
# 126312  59.290245    GSW   Warriors      105  1813.6349  1822.2881
# 126313  68.519516    CLE  Cavaliers       97  1700.7391  1692.0859
#
#        game_location game_result  forecast notes
# 126311             A           L  0.234435   NaN
# ...

# %% [markdown]
# ## Displaying Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %% [markdown]
# ## Showing Basics Statistics

# %%
df.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %% [markdown]
# ## Exploring Your Dataset

# %%
df["team_id"].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# INJ      60
# PIT      60
# DTF      60
# TRH      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df["fran_id"].value_counts()
# Out:
# Lakers          6024
# Celtics         5997
# Knicks          5769
# Warriors        5657
# Pistons         5650
# Sixers          5644
# Hawks           5572
# Kings           5475
# Wizards         4582
# Spurs           4309
# Bulls           4307
# Pacers          4227
# Thunder         4178
# Rockets         4154
# Nuggets         4120
# Nets            4106
# Suns            4080
# Bucks           4034
# Trailblazers    3870
# Cavaliers       3810
# Clippers        3733
# Jazz            3555
# Mavericks       3013
# Heat            2371
# Pelicans        2254
# Magic           2207
# Timberwolves    2131
# Grizzlies       1657
# Raptors         1634
# Hornets          894
# Colonels         846
# Squires          799
# Spirits          777
# Stars            756
# Sounds           697
# Baltimore        467
# Floridians       440
# Condors          430
# Capitols         291
# Olympians        282
# Sails            274
# Stags            260
# Bombers          249
# ...

# %%
df.loc[df["fran_id"]== "Lakers", "team_id"].value_counts()
# Out:
# LAL    5078
# MNL     946
# Name: team_id, dtype: int64

# %%
df.loc[df["team_id"]== "MNL", "date_game"].min()
# Out:
# '1/1/1949'

# %%
df.loc[df["team_id"]== "MNL", "date_game"].max()
# Out:
# '4/9/1959'

# %%
df.loc[df["team_id"]== "MNL", "date_game"].agg(("min", "max"))
# Out:
# min    1/1/1949
# max    4/9/1959
# Name: date_game, dtype: object

# %%
df.loc[df["team_id"]=="BOS", "pts"].sum()
# Out:
# 626484

# %% [markdown]
# ## Understanding Series Objects

# %%
revenues = pd.Series([5555, 7000, 1980])
print(revenues)
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %% [markdown]
# ### Revenues.values VS Revenues.index
# - Revenues.values : mengembalikan nilai dalam Seri
# - Revenues.index : mengembalikan indeks posisi

# %%
revenues.values
# Out:
# array([5555, 7000, 1980], dtype=int64)

# %%
revenues.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
city_revenues = pd.Series (
    [4200, 8000, 6500],
    index = ["Amsterdam", "Toronto", "Tokyo"]
)
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_employee_count = pd.Series({"Amsterdam": 5, "Tokyo": 8})
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
"Tokyo" in city_employee_count
# Out:
# True

# %%
"New York" in city_employee_count
# Out:
# False

# %% [markdown]
# ### Understanding DataFrame Objects

# %%
city_data = pd.DataFrame({
    "Revenue": city_revenues,
    "employee_count" : city_employee_count
})

# %%
city_data
# Out:
#            Revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.values
# Out:
# array([[4.2e+03, 5.0e+00],
#        [6.5e+03, 8.0e+00],
#        [8.0e+03,     nan]])

# %%
city_data.axes
# Out:
# [Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object'),
#  Index(['Revenue', 'employee_count'], dtype='object')]

# %%
city_data.axes[0]
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.axes[1]
# Out:
# Index(['Revenue', 'employee_count'], dtype='object')

# %%
city_data.keys()
# Out:
# Index(['Revenue', 'employee_count'], dtype='object')

# %%
"Amsterdam" in city_data
# Out:
# False

# %%
"Revenue" in city_data
# Out:
# True

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
"points" in df.keys()
# Out:
# False

# %%
"pts" in df.keys()
# Out:
# True

# %% [markdown]
# ## Accessing Series Elements

# %%
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_revenues["Toronto"]
# Out:
# 8000

# %%
city_revenues[2]
# Out:
# 6500

# %%
city_revenues[-1]
# Out:
# 6500

# %%
city_revenues[1:]
# Out:
# Toronto    8000
# Tokyo      6500
# dtype: int64

# %%
city_revenues["Toronto":]
# Out:
# Toronto    8000
# Tokyo      6500
# dtype: int64

# %% [markdown]
# ### Using .loc and .iloc

# %%
colors = pd.Series(
    ["red", "purple", "blue", "green", "yellow"],
    index=[1,2,3,5,8]
)

# %%
colors
# Out:
# 1       red
# 2    purple
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors.loc[1]
# Out:
# 'red'

# %%
colors.iloc[1]
# Out:
# 'purple'

# %%
colors.iloc[3:8]
# Out:
# 5     green
# 8    yellow
# dtype: object

# %%
colors.loc[3:8]
# Out:
# 3      blue
# 5     green
# 8    yellow
# dtype: object

# %%
colors.iloc[-2]
# Out:
# 'green'

# %% [markdown]
# ## Using the Indexing Operator

# %%
city_data["Revenue"]
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: Revenue, dtype: int64

# %%
city_data.Revenue
# Out:
# Amsterdam    4200
# Tokyo        6500
# Toronto      8000
# Name: Revenue, dtype: int64

# %% [markdown]
# Terdapat situasi dimana mengakses elemen DataFrame dengan notasi titik mungkin tidak berfungsi atau dapat menimbulkan kesalahan. yaitu saat nama kolom bertepatan dengan atribut DataFrame atau method

# %%
toys = pd.DataFrame([
    {"name": "ball", "shape": "sphere"},
    {"name": "Rubik's cube", "shape": "cube"}
])

# %%
toys["shape"]
# Out:
# 0    sphere
# 1      cube
# Name: shape, dtype: object

# %%
toys.shape
# Out:
# (2, 2)

# %% [markdown]
# ## Using .loc and .iloc
# pada DataFrame

# %%
city_data
# Out:
#            Revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.loc["Amsterdam"]
# Out:
# Revenue           4200.0
# employee_count       5.0
# Name: Amsterdam, dtype: float64

# %%
city_data.loc["Tokyo": "Toronto"]
# Out:
#          Revenue  employee_count
# Tokyo       6500             8.0
# Toronto     8000             NaN

# %%
city_data.iloc[1]
# Out:
# Revenue           6500.0
# employee_count       8.0
# Name: Tokyo, dtype: float64

# %% [markdown]
# using .loc and .iloc in big data

# %%
df.iloc[-2]
# Out:
# gameorder               63157
# game_id          201506170CLE
# lg_id                     NBA
# _iscopy                     0
# year_id                  2015
# date_game           6/16/2015
# seasongame                102
# is_playoffs                 1
# team_id                   CLE
# fran_id             Cavaliers
# pts                        97
# elo_i               1700.7391
# elo_n               1692.0859
# win_equiv           59.290245
# opp_id                    GSW
# opp_fran             Warriors
# opp_pts                   105
# opp_elo_i           1813.6349
# opp_elo_n           1822.2881
# game_location               H
# game_result                 L
# forecast              0.48145
# notes                     NaN
# Name: 126312, dtype: object

# %%
city_data.loc["Amsterdam": "Tokyo", "Revenue"]
# Out:
# Amsterdam    4200
# Tokyo        6500
# Name: Revenue, dtype: int64

# %%
df.loc[5555:5559, ["fran_id", "opp_fran", "pts", "opp_pts"]]
# Out:
#       fran_id  opp_fran  pts  opp_pts
# 5555  Pistons  Warriors   83       56
# 5556  Celtics    Knicks   95       74
# 5557   Knicks   Celtics   74       95
# 5558    Kings    Sixers   81       86
# 5559   Sixers     Kings   86       81

# %% [markdown]
# ## Quering Dataset

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
current_decade = df[df["year_id"] > 2010]

# %%
current_decade
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 113656      56829  201010260BOS   NBA        1     2011  10/26/2010
# 113657      56829  201010260BOS   NBA        0     2011  10/26/2010
# 113658      56830  201010260LAL   NBA        1     2011  10/26/2010
# 113659      56830  201010260LAL   NBA        0     2011  10/26/2010
# 113660      56831  201010260POR   NBA        1     2011  10/26/2010
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# ...

# %%
current_decade.shape
# Out:
# (12658, 23)

# %%
#memilih baris dimana field bukan null

games_with_notes = df[df["notes"].notnull()]
games_with_notes
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 930           466  194801300BLB   NBA        1     1948   1/30/1948
# 931           466  194801300BLB   NBA        0     1948   1/30/1948
# 1084          543  194803230CHS   NBA        1     1948   3/23/1948
# 1085          543  194803230CHS   NBA        0     1948   3/23/1948
# 1088          545  194803250CHS   NBA        1     1948   3/25/1948
# ...           ...           ...   ...      ...      ...         ...
# 122207      61104  201401160ATL   NBA        0     2014   1/16/2014
# 123916      61959  201411120MIN   NBA        1     2015  11/12/2014
# 123917      61959  201411120MIN   NBA        0     2015  11/12/2014
# 124862      62432  201501150MIL   NBA        0     2015   1/15/2015
# 124863      62432  201501150MIL   NBA        1     2015   1/15/2015
#
#         seasongame  is_playoffs team_id       fran_id  pts      elo_i  \
# 930             28            0     WSC      Capitols   71  1469.3469
# ...

# %%
#menggunakan .str.endswith() untuk memfilter data yg berakhiran "ers"

ers = df[df["fran_id"].str.endswith("ers")]

# %%
ers.shape
# Out:
# (27797, 23)

# %%
#Melakukan pencarian game Baltimore yg kedua tim mencetak > 100 poin
df[
    (df["_iscopy"] == 0) &      #untuk menyertakan entri yg bukan duplikat
    (df["pts"] > 100) &
    (df["opp_pts"] > 100) &
    (df["team_id"] == "BLB")
]
# Out:
#       gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 1726        864  194902260BLB   NBA        0     1949  2/26/1949          53
# 4890       2446  195301100BLB   NBA        0     1953  1/10/1953          32
# 4909       2455  195301140BLB   NBA        0     1953  1/14/1953          34
# 5208       2605  195303110BLB   NBA        0     1953  3/11/1953          66
# 5825       2913  195402220BLB   NBA        0     1954  2/22/1954          60
#
#       is_playoffs team_id    fran_id  pts      elo_i      elo_n  win_equiv  \
# 1726            0     BLB  Baltimore  114  1421.9351  1419.4280  38.557545
# 4890            0     BLB  Baltimore  126  1328.6687  1356.6470  25.797792
# 4909            0     BLB  Baltimore  104  1349.8323  1346.3594  24.876236
# 5208            0     BLB  Baltimore  107  1284.5239  1282.2396  19.579676
# 5825            0     BLB  Baltimore  110  1303.7493  1301.9685  20.736986
#
# ...

# %%
df[
    (df["_iscopy"] == 0) &
    (df["year_id"] == 1992) &
    (df["team_id"].str.startswith("LA")) &
    (df["notes"].notnull())
]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id date_game  seasongame  \
# 68901      34451  199205030LAC   NBA        0     1992  5/3/1992          86
# 68903      34452  199205030LAL   NBA        0     1992  5/3/1992          86
#
#        is_playoffs team_id   fran_id  pts      elo_i      elo_n  win_equiv  \
# 68901            1     LAC  Clippers  115  1546.9009  1556.0005  47.888252
# 68903            1     LAL    Lakers   76  1489.6460  1474.3994  39.395412
#
#       opp_id      opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location  \
# 68901    UTA          Jazz      107  1647.5092  1638.4095             H
# 68903    POR  Trailblazers      102  1655.1210  1670.3677             H
#
#       game_result  forecast                                       notes
# 68901           W  0.499125  at Anaheim, CA (Anaheim Convention Center)
# 68903           L  0.406874                            at Las Vegas, NV

# %% [markdown]
# ## Grouping and Aggregating Data

# %%
city_revenues.sum()
# Out:
# 18700

# %%
city_revenues.max()
# Out:
# 8000

# %%
city_revenues.mean()
# Out:
# 6233.333333333333

# %%
city_revenues.min()
# Out:
# 4200

# %%
points = df["pts"]

# %%
points.sum()
# Out:
# 12976235

# %%
df.head(3)
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts   elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0  1309.6521  42.012257    NYK
#
#   opp_fran  opp_pts  opp_elo_i  opp_elo_n game_location game_result  forecast  \
# 0   Knicks       68  1300.0000  1306.7233             H           L  0.640065
# 1  Huskies       66  1300.0000  1293.2767             A           W  0.359935
# 2   Knicks       47  1306.7233  1297.0712             H           W  0.631101
#
#   notes
# 0   NaN
# 1   NaN
# 2   NaN

# %%
df.groupby("fran_id", sort=False)["pts"].sum()  #sort = False jika tidak ingin mengurutkan
# Out:
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# ...

# %%
df[
    (df["fran_id"] == "Spurs") &
    (df["year_id"] > 2010)
].groupby(["year_id", "game_result"])["game_id"].count()
# Out:
# year_id  game_result
# 2011     L              25
#          W              63
# 2012     L              20
#          W              60
# 2013     L              30
#          W              73
# 2014     L              27
#          W              78
# 2015     L              31
#          W              58
# Name: game_id, dtype: int64

# %% [markdown]
# Lihat musim Golden State Warriors 2014-15 (year_id: 2015).
#
# Berapa banyak kemenangan dan kekalahan yg mereka cetak selama musim reguler dan babak playoff?

# %%
df[
    (df["year_id"] == 2015) &
    (df["fran_id"] == "Warriors")
].groupby(["is_playoffs", "game_result"])["game_id"].count()
# Out:
# is_playoffs  game_result
# 0            L              15
#              W              67
# 1            L               5
#              W              16
# Name: game_id, dtype: int64

# %% [markdown]
# ## Manipulating Columns

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
nba = df.copy()

# %%
nba.shape
# Out:
# (126314, 23)

# %%
# Menentukan kolom baru berdasarkan yg sudah ada:

nba["difference"] = df.pts - df.opp_pts

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  pts      elo_i      elo_n  \
# 0                1            0     TRH    Huskies   66  1300.0000  1293.2767
# ...

# %%
nba.shape
# Out:
# (126314, 24)

# %%
nba["difference"].max()
# Out:
# 68

# %%
#mengganti nama kolom:

renamed_nba = nba.rename(
    columns={"game_result" :"result", "game_location" : "location"}
             )

renamed_nba.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  pts      elo_i      elo_n  win_equiv opp_id  \
# 0            0     TRH  Huskies   66  1300.0000  1293.2767  40.294830    NYK
# 1            0     NYK   Knicks   68  1300.0000  1306.7233  41.705170    TRH
# 2            0     CHS    Stags   63  1300.0000  1309.6521  42.012257    NYK
# 3            0     NYK   Knicks   47  1306.7233  1297.0712  40.692783    CHS
# 4            0     DTF  Falcons   33  1300.0000  1279.6189  38.864048    WSC
#
# ...

# %%
#menghapus kolom yg sudah ada:
 
print(nba.shape)

elo_columns = ["elo_i", "elo_n", "opp_elo_i", "opp_elo_n"]
nba.drop(elo_columns, inplace=True, axis=1)    #inplace = True untuk memanipulasi dataframe asli scr langsung
print(nba.shape)
# Out:
# (126314, 24)
# (126314, 20)

# %% [markdown]
# ## Specifing Data Types

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  win_equiv      126314 non-null  float64
#  12  opp_id         126314 non-null  object
#  13  opp_fran       126314 non-null  object
#  14  opp_pts        126314 non-null  int64
#  15  game_location  126314 non-null  object
#  16  game_result    126314 non-null  object
# ...

# %%
nba["date_game"] = pd.to_datetime(nba["date_game"])
#.to_datetime() untuk menetapkan semua tgl game sebagai objek datetime

# %%
nba["game_location"].nunique()
# Out:
# 3

# %%
nba["game_location"].value_counts()
# Out:
# H    63138
# A    63138
# N       38
# Name: game_location, dtype: int64

# %%
nba["game_location"] = pd.Categorical(nba["game_location"])

# %%
nba["game_location"].dtype
# Out:
# CategoricalDtype(categories=['A', 'H', 'N'], ordered=False)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  win_equiv      126314 non-null  float64
#  12  opp_id         126314 non-null  object
#  13  opp_fran       126314 non-null  object
#  14  opp_pts        126314 non-null  int64
#  15  game_location  126314 non-null  category
#  16  game_result    126314 non-null  object
# ...

# %% [markdown]
# ## Missing Values

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  datetime64[ns]
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  win_equiv      126314 non-null  float64
#  12  opp_id         126314 non-null  object
#  13  opp_fran       126314 non-null  object
#  14  opp_pts        126314 non-null  int64
#  15  game_location  126314 non-null  category
#  16  game_result    126314 non-null  object
# ...

# %%
#menghapus baris dg nilai yg hilang:

rows_without_missing_data = nba.dropna()

# %%
rows_without_missing_data.shape
# Out:
# (5424, 20)

# %%
#menghapus kolom yg bermasalah:

data_without_missing_columns = nba.dropna(axis=1)

# %%
data_without_missing_columns.shape
# Out:
# (126314, 19)

# %%
data_with_default_notes = nba.copy()

# %%
data_with_default_notes["notes"].fillna(
    value="no notes at all",
inplace=True
)

# %%
data_with_default_notes["notes"].describe()
# Out:
# count              126314
# unique                232
# top       no notes at all
# freq               120890
# Name: notes, dtype: object

# %% [markdown]
# ## Invalid Values

# %%
nba.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts      win_equiv        opp_pts  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982      41.707889     102.729982
# std         0.244499      14.814845      10.627332      14.814845
# min         0.000000       0.000000      10.152501       0.000000
# ...

# %%
nba[nba["pts"] == 0]
# Out:
#        gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 26684      13343  197210260VIR   ABA        1     1973 1972-10-26           7
#
#        is_playoffs team_id  fran_id  pts  win_equiv opp_id opp_fran  opp_pts  \
# 26684            0     DNR  Nuggets    0  40.408863    VIR  Squires        2
#
#       game_location game_result  forecast                           notes  \
# 26684             A           L  0.328948  at Richmond VA; forfeit to VIR
#
#        difference
# 26684          -2

# %% [markdown]
# ### Inconsistent values

# %%
nba[(nba["pts"] > nba["opp_pts"]) & (nba["game_result"] != 'W')].empty
# Out:
# True

# %%
nba[(nba["pts"] < nba["opp_pts"]) & (nba["game_result"] != 'L')].empty
# Out:
# True

# %% [markdown]
# ## Combining Multiple Dataset

# %%
further_city_data = pd.DataFrame(
    {"Revenue" : [7000, 3400], "employee_count": [2,2]},
    index = ["New York", "Barcelona"]
)

# %%
further_city_data
# Out:
#            Revenue  employee_count
# New York      7000               2
# Barcelona     3400               2

# %%
city_data
# Out:
#            Revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
#menggabungkan dataset:

all_city_data = pd.concat([city_data, further_city_data], sort=False)

# %%
all_city_data
# Out:
#            Revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
city_countries = pd.DataFrame({
    "country": ["Holland", "Japan", "Holland", "Canada", "Spain"],
    "capital": [1,1,0,0,0]},
    index= ["Amsterdam", "Tokyo", "Rotterdam", "Toronto", "Barcelona"])

# %%
city_countries
# Out:
#            country  capital
# Amsterdam  Holland        1
# Tokyo        Japan        1
# Rotterdam  Holland        0
# Toronto     Canada        0
# Barcelona    Spain        0

# %%
all_city_data
# Out:
#            Revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
#concat mampu menambahkan baris (axis = 0) dan kolom (axis = 1)
cities = pd.concat([all_city_data, city_countries], axis=1, sort=False)

# %%
cities
# Out:
#            Revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
#menggabungkan kota yg hanya muncul di kedua objek DataFrame:

pd.concat([all_city_data, city_countries], axis=1, join="inner")
# Out:
#            Revenue  employee_count  country  capital
# Amsterdam     4200             5.0  Holland        1
# Tokyo         6500             8.0    Japan        1
# Toronto       8000             NaN   Canada        0
# Barcelona     3400             2.0    Spain        0

# %%
#menyatukan beberapa dataset menggunakan .merge:

countries = pd.DataFrame ({
    "population_millions": [17, 127, 37],
    "continent": ["Europe", "Asia", "North America"]
}, index = ["Holland", "Japan", "Canada"])

# %%
countries
# Out:
#          population_millions      continent
# Holland                   17         Europe
# Japan                    127           Asia
# Canada                    37  North America

# %%
cities
# Out:
#            Revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      1.0
# Toronto     8000.0             NaN   Canada      0.0
# New York    7000.0             2.0      NaN      NaN
# Barcelona   3400.0             2.0    Spain      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
#merge melakukan inner join scr default

pd.merge(cities, countries, left_on="country", right_index=True)
# Out:
#            Revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                   17
# Rotterdam      NaN             NaN  Holland      0.0                   17
# Tokyo       6500.0             8.0    Japan      1.0                  127
# Toronto     8000.0             NaN   Canada      0.0                   37
#
#                continent
# Amsterdam         Europe
# Rotterdam         Europe
# Tokyo               Asia
# Toronto    North America

# %%
#jika ingin menampilkan semua nama kota harus menggunakan how:

pd.merge(cities, countries, left_on="country", right_index=True,
        how="left")
# Out:
#            Revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                 17.0
# Tokyo       6500.0             8.0    Japan      1.0                127.0
# Toronto     8000.0             NaN   Canada      0.0                 37.0
# New York    7000.0             2.0      NaN      NaN                  NaN
# Barcelona   3400.0             2.0    Spain      0.0                  NaN
# Rotterdam      NaN             NaN  Holland      0.0                 17.0
#
#                continent
# Amsterdam         Europe
# Tokyo               Asia
# Toronto    North America
# New York             NaN
# Barcelona            NaN
# Rotterdam         Europe

# %% [markdown]
# ## Visualizing Pandas DataFrame

# %%
# %matplotlib inline

# %%
nba
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947 1946-11-01
# 1               1  194611010TRH   NBA        1     1947 1946-11-01
# 2               2  194611020CHS   NBA        0     1947 1946-11-02
# 3               2  194611020CHS   NBA        1     1947 1946-11-02
# 4               3  194611020DTF   NBA        0     1947 1946-11-02
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015 2015-06-11
# 126310      63156  201506140GSW   NBA        0     2015 2015-06-14
# 126311      63156  201506140GSW   NBA        1     2015 2015-06-14
# 126312      63157  201506170CLE   NBA        0     2015 2015-06-16
# 126313      63157  201506170CLE   NBA        1     2015 2015-06-16
#
#         seasongame  is_playoffs team_id    fran_id  pts  win_equiv opp_id  \
# 0                1            0     TRH    Huskies   66  40.294830    NYK
# ...

# %%
nba[nba["fran_id"] == "Knicks"].groupby("year_id")["pts"].sum().plot()
# Out:
# <AxesSubplot:xlabel='year_id'>

# %%
nba[nba["fran_id"] == "Knicks"].groupby("year_id")["pts"].sum()
# Out:
# year_id
# 1947    4234
# 1948    3815
# 1949    5253
# 1950    5924
# 1951    6814
#         ...
# 2011    9097
# 2012    6872
# 2013    9259
# 2014    8084
# 2015    7535
# Name: pts, Length: 69, dtype: int64

# %%
nba["fran_id"].value_counts().head(10).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
nba["fran_id"].value_counts().head(10)
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Sixers      5644
# Hawks       5572
# Kings       5475
# Wizards     4582
# Spurs       4309
# Name: fran_id, dtype: int64

# %% [markdown]
# #### Membuat Plot

# %% [markdown]
# Beberapa argumen untuk membuat jenis plot yg berbeda dengan pandas:
# - 'line': line plot (default)
# - 'bar' : vertical bar plot
# - 'barh' : horizontal bar plot
# - 'hist' : histogram
# - 'box' : boxplot
# - 'kde' : kernel density estimation plot
# - 'density' : same as 'kde'
# - 'area' : area plot
# - 'pie' : pie plot
# - 'scatter' : scatter plot
# - 'hexbin' : hexbin plot

# %%
nba["fran_id"].value_counts().head(10).plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
nba["fran_id"].value_counts().head(10).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
nba["fran_id"].value_counts().head(10).plot(kind="barh")
# Out:
# <AxesSubplot:>
